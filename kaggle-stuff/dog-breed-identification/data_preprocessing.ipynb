# %%
#################################################################################
############### Generate data for training and validating  ######################
#################################################################################
import pandas as pd
import numpy as np

import os
import shutil

def mkdirIfNotExist(directory):
    if not os.path.exists(directory):
        os.mkdir(directory)
    return directory

original_train_dir = './data/train'

train_labels = np.array(pd.read_csv('./data/labels.csv'))
classes, counts = np.unique(train_labels[:, 1], return_counts=True)

print("There are %d classes." % classes.size)

base_dir = mkdirIfNotExist('./data_gen')
train_dir = mkdirIfNotExist(os.path.join(base_dir, 'train'))
validation_dir = mkdirIfNotExist(os.path.join(base_dir, 'validation'))
# Out:
# There are 120 classes.

# %%
for c in classes[:]:
    mkdirIfNotExist(os.path.join(train_dir, c))
    mkdirIfNotExist(os.path.join(validation_dir, c))


def copyIfNotExist(fnames, src_dir, dst_dir):
    nCopied = 0
    for fname in fnames:
        src = os.path.join(src_dir, fname)
        dst = os.path.join(dst_dir, fname)
        if not os.path.exists(dst):
            shutil.copyfile(src, dst)
            nCopied += 1
    if nCopied > 0:
        print("Copied %d to %s" % (nCopied, dst_dir))


# This will split available labeled data to train-validation sets
train_ratio = 1
for c in classes[:]:
    fnames = train_labels[train_labels[:, 1] == c][:, 0]
    fnames = ['{}.jpg'.format(name) for name in fnames]
    idx = int(len(fnames) * (1 - train_ratio))
    val_fnames = fnames[:idx]
    train_fnames = fnames[idx:]
    train_class_dir = os.path.join(train_dir, c)
    validation_class_dir = os.path.join(validation_dir, c)
    copyIfNotExist(train_fnames, original_train_dir, train_class_dir)
    copyIfNotExist(val_fnames, original_train_dir, validation_class_dir)
# Out:
# Copied 80 to ./data_gen/train/affenpinscher
# Copied 116 to ./data_gen/train/afghan_hound
# Copied 86 to ./data_gen/train/african_hunting_dog
# Copied 107 to ./data_gen/train/airedale
# Copied 74 to ./data_gen/train/american_staffordshire_terrier
# Copied 78 to ./data_gen/train/appenzeller
# Copied 102 to ./data_gen/train/australian_terrier
# Copied 110 to ./data_gen/train/basenji
# Copied 82 to ./data_gen/train/basset
# Copied 105 to ./data_gen/train/beagle
# Copied 89 to ./data_gen/train/bedlington_terrier
# Copied 114 to ./data_gen/train/bernese_mountain_dog
# Copied 77 to ./data_gen/train/black-and-tan_coonhound
# Copied 102 to ./data_gen/train/blenheim_spaniel
# Copied 85 to ./data_gen/train/bloodhound
# Copied 85 to ./data_gen/train/bluetick
# Copied 72 to ./data_gen/train/border_collie
# Copied 91 to ./data_gen/train/border_terrier
# Copied 75 to ./data_gen/train/borzoi
# Copied 87 to ./data_gen/train/boston_bull
# Copied 86 to ./data_gen/train/bouvier_des_flandres
# Copied 75 to ./data_gen/train/boxer
# Copied 67 to ./data_gen/train/brabancon_griffon
# Copied 66 to ./data_gen/train/briard
# Copied 73 to ./data_gen/train/brittany_spaniel
# Copied 75 to ./data_gen/train/bull_mastiff
# Copied 106 to ./data_gen/train/cairn
# Copied 76 to ./data_gen/train/cardigan
# Copied 83 to ./data_gen/train/chesapeake_bay_retriever
# Copied 71 to ./data_gen/train/chihuahua
# Copied 93 to ./data_gen/train/chow
# Copied 80 to ./data_gen/train/clumber
# Copied 74 to ./data_gen/train/cocker_spaniel
# Copied 87 to ./data_gen/train/collie
# Copied 72 to ./data_gen/train/curly-coated_retriever
# Copied 89 to ./data_gen/train/dandie_dinmont
# Copied 76 to ./data_gen/train/dhole
# Copied 80 to ./data_gen/train/dingo
# Copied 74 to ./data_gen/train/doberman
# Copied 86 to ./data_gen/train/english_foxhound
# Copied 83 to ./data_gen/train/english_setter
# Copied 75 to ./data_gen/train/english_springer
# Copied 115 to ./data_gen/train/entlebucher
# Copied 66 to ./data_gen/train/eskimo_dog
# Copied 72 to ./data_gen/train/flat-coated_retriever
# Copied 70 to ./data_gen/train/french_bulldog
# Copied 69 to ./data_gen/train/german_shepherd
# Copied 75 to ./data_gen/train/german_short-haired_pointer
# Copied 69 to ./data_gen/train/giant_schnauzer
# Copied 67 to ./data_gen/train/golden_retriever
# Copied 81 to ./data_gen/train/gordon_setter
# Copied 75 to ./data_gen/train/great_dane
# Copied 111 to ./data_gen/train/great_pyrenees
# Copied 82 to ./data_gen/train/greater_swiss_mountain_dog
# Copied 82 to ./data_gen/train/groenendael
# Copied 91 to ./data_gen/train/ibizan_hound
# Copied 88 to ./data_gen/train/irish_setter
# Copied 82 to ./data_gen/train/irish_terrier
# Copied 78 to ./data_gen/train/irish_water_spaniel
# Copied 101 to ./data_gen/train/irish_wolfhound
# Copied 92 to ./data_gen/train/italian_greyhound
# Copied 105 to ./data_gen/train/japanese_spaniel
# Copied 81 to ./data_gen/train/keeshond
# Copied 86 to ./data_gen/train/kelpie
# Copied 82 to ./data_gen/train/kerry_blue_terrier
# Copied 67 to ./data_gen/train/komondor
# Copied 71 to ./data_gen/train/kuvasz
# Copied 84 to ./data_gen/train/labrador_retriever
# Copied 99 to ./data_gen/train/lakeland_terrier
# Copied 106 to ./data_gen/train/leonberg
# Copied 90 to ./data_gen/train/lhasa
# Copied 81 to ./data_gen/train/malamute
# Copied 73 to ./data_gen/train/malinois
# Copied 117 to ./data_gen/train/maltese_dog
# Copied 80 to ./data_gen/train/mexican_hairless
# Copied 102 to ./data_gen/train/miniature_pinscher
# Copied 79 to ./data_gen/train/miniature_poodle
# Copied 78 to ./data_gen/train/miniature_schnauzer
# Copied 91 to ./data_gen/train/newfoundland
# Copied 83 to ./data_gen/train/norfolk_terrier
# Copied 95 to ./data_gen/train/norwegian_elkhound
# Copied 78 to ./data_gen/train/norwich_terrier
# Copied 87 to ./data_gen/train/old_english_sheepdog
# Copied 69 to ./data_gen/train/otterhound
# Copied 96 to ./data_gen/train/papillon
# Copied 75 to ./data_gen/train/pekinese
# Copied 92 to ./data_gen/train/pembroke
# Copied 111 to ./data_gen/train/pomeranian
# Copied 94 to ./data_gen/train/pug
# Copied 72 to ./data_gen/train/redbone
# Copied 88 to ./data_gen/train/rhodesian_ridgeback
# Copied 76 to ./data_gen/train/rottweiler
# Copied 84 to ./data_gen/train/saint_bernard
# Copied 99 to ./data_gen/train/saluki
# Copied 109 to ./data_gen/train/samoyed
# Copied 86 to ./data_gen/train/schipperke
# Copied 82 to ./data_gen/train/scotch_terrier
# Copied 126 to ./data_gen/train/scottish_deerhound
# Copied 88 to ./data_gen/train/sealyham_terrier
# Copied 76 to ./data_gen/train/shetland_sheepdog
# Copied 112 to ./data_gen/train/shih-tzu
# Copied 95 to ./data_gen/train/siberian_husky
# Copied 90 to ./data_gen/train/silky_terrier
# Copied 71 to ./data_gen/train/soft-coated_wheaten_terrier
# Copied 79 to ./data_gen/train/staffordshire_bullterrier
# Copied 79 to ./data_gen/train/standard_poodle
# Copied 72 to ./data_gen/train/standard_schnauzer
# Copied 78 to ./data_gen/train/sussex_spaniel
# Copied 69 to ./data_gen/train/tibetan_mastiff
# Copied 107 to ./data_gen/train/tibetan_terrier
# Copied 80 to ./data_gen/train/toy_poodle
# Copied 79 to ./data_gen/train/toy_terrier
# Copied 70 to ./data_gen/train/vizsla
# Copied 69 to ./data_gen/train/walker_hound
# Copied 85 to ./data_gen/train/weimaraner
# Copied 79 to ./data_gen/train/welsh_springer_spaniel
# Copied 81 to ./data_gen/train/west_highland_white_terrier
# Copied 95 to ./data_gen/train/whippet
# Copied 82 to ./data_gen/train/wire-haired_fox_terrier
# Copied 82 to ./data_gen/train/yorkshire_terrier
